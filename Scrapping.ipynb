# %%
import requests

from bs4 import BeautifulSoup

import pandas as pd

# %%
req = requests.get('https://factba.se/topic/twitter')
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.content, 'lxml')

divs = soup.find_all('div', {'class': 'col-lg-9'})

df = pd.DataFrame(columns = ['content', 'date', 'author', 'source'])

media = soup.find_all('div', {'class':"media-body topic-media-block"})

for stuffs in media: 
     for talk in tweet.find_all('div', {'class':"col-lg-12"}):
            content = talk.text
            date = tweet.find_all('div', {'class':"col-lg-3"})[0].text
            author = tweet.find_all('div', {'class':"col-lg-3"})[1].text
            source = tweet.find_all('div', {'class':"col-lg-3"})[2].text
            df.loc[len(df)] = [content ,date , author, source]

# %%
df
# Out:
#                                                 content  \
# 0     Together, we will face this challenge as a nat...
# 1     Consumer Confidence in February Highest Since ...
# 2     Manufacturing in U.S. Expands at Fastest Pace ...
# 3     Unemployment filings are at their lowest level...
# 4     Our Steel and Aluminum industries (and many ot...
# 5     Many ideas, some good & some not so good, emer...
# 6     It was an honor to welcome bipartisan members ...
# 7     Today we honor Billy Graham as only three priv...
# 8     Starting at a small Bible School in Florida, B...
# 9     Today, in the center of this great Chamber lie...
# 10    Why is A.G. Jeff Sessions asking the Inspector...
# 11    45 year low on illegal border crossings this y...
# 12    I have decided that sections of the Wall that ...
# 13    The Heritage Foundation has just stated that 6...
# 14    Big legal win today. U.S. judge sided with the...
# 15    Such a beautiful map, thank you! https://t.co/...
# ...

# %%
df.to_csv('trump_tweet_1.csv',index=False)

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.Chrome()

browser.get('https://factba.se/topic/twitter')
time.sleep(1)

# %%
elem = browser.find_element_by_xpath('/html/body')

# %%
elem.send_keys(Keys.PAGE_DOWN)

# %%
soup = BeautifulSoup(browser.page_source, 'lxml')
#elem = browser.find_element_by_class_name("media-body")

page_no = 20

while page_no > 0:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    page_no -= page_no

divs = soup.find_all('div', {'class': 'col-lg-9'})

df = pd.DataFrame(columns = ['content', 'date', 'author', 'source'])

media = soup.find_all('div', {'class':"media-body topic-media-block"})

for stuffs in media: 
     for talk in tweet.find_all('div', {'class':"col-lg-12"}):
            content = talk.text
            date = tweet.find_all('div', {'class':"col-lg-3"})[0].text
            author = tweet.find_all('div', {'class':"col-lg-3"})[1].text
            source = tweet.find_all('div', {'class':"col-lg-3"})[2].text
            df.loc[len(df)] = [content ,date , author, source]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-363ea6034766> in <module>()
#      21             author = tweet.find_all('div', {'class':"col-lg-3"})[1].text
#      22             source = tweet.find_all('div', {'class':"col-lg-3"})[2].text
# ---> 23             df.loc[len(df)] = [content ,date , author, source]
#      24
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     423                                        name=indexer)
#     424
# ...

# %%
df
# Out:
#                                                 content  \
# 0     Together, we will face this challenge as a nat...
# 1     Consumer Confidence in February Highest Since ...
# 2     Manufacturing in U.S. Expands at Fastest Pace ...
# 3     Unemployment filings are at their lowest level...
# 4     Our Steel and Aluminum industries (and many ot...
# 5     Many ideas, some good & some not so good, emer...
# 6     It was an honor to welcome bipartisan members ...
# 7     Today we honor Billy Graham as only three priv...
# 8     Starting at a small Bible School in Florida, B...
# 9     Today, in the center of this great Chamber lie...
# 10    Why is A.G. Jeff Sessions asking the Inspector...
# 11    45 year low on illegal border crossings this y...
# 12    I have decided that sections of the Wall that ...
# 13    The Heritage Foundation has just stated that 6...
# 14    Big legal win today. U.S. judge sided with the...
# 15    Such a beautiful map, thank you! https://t.co/...
# ...
